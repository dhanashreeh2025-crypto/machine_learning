# %% [markdown]
# # Feature selection

# %%
from warnings import filterwarnings

filterwarnings("ignore")

# %%
import pandas as pd

df = pd.read_csv("training_Set.csv", na_values=["", "NA"], keep_default_na=False)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Target Sales price

# %% [markdown]
# # Step 2 - Perform basic data quality checks

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df.shape
# Out:
# (1460, 81)

# %%
m = df.isna().sum()
m[m > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# Cardinality is checked only on categorical features
df.select_dtypes(include="object").nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        4
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       4
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
def get_high_card(df, threshold=0.9):
    cat_unique = df.select_dtypes(include="object").nunique()
    rows = len(df)
    cardinality = cat_unique / rows
    high_card = cardinality[cardinality >= threshold]
    print(high_card)
    return high_card.index.tolist()

# %%
high_card = get_high_card(df, threshold=0.9)
print(high_card)
# Out:
# Series([], dtype: float64)
# []

# %%
df = df.drop(columns=high_card)
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
X = df.drop(columns=["Id", "SalePrice"])
Y = df["SalePrice"]

# %%
X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
Y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
#  # Step 4 - Train Test Split

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=21)

# %%
xtrain.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 710           30       RL         56.0     4130   Pave   NaN      IR1
# 1098          50       RM         50.0     6000   Pave   NaN      Reg
# 1286          20       RL          NaN     9790   Pave   NaN      Reg
# 992           60       RL         80.0     9760   Pave   NaN      Reg
# 631          120       RL         34.0     4590   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 710          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1098         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1286         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 992          Lvl    AllPub    Inside  ...           0        0    NaN  MnWw
# 631          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 710          NaN       0       7    2008        WD         Normal
# 1098         NaN       0       7    2009        WD         Normal
# 1286         NaN       0       6    2010        WD         Normal
# 992          NaN       0       7    2007        WD         Normal
# 631          NaN       0       8    2007        WD         Normal
#
# [5 rows x 79 columns]

# %%
ytrain.head()
# Out:
# 710      52000
# 1098    128000
# 1286    143000
# 992     187000
# 631     209500
# Name: SalePrice, dtype: int64

# %%
xtest.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 880           20       RL         60.0     7024   Pave   NaN      Reg
# 605           60       RL         85.0    13600   Pave   NaN      Reg
# 1166          20       RL         64.0    10475   Pave   NaN      IR1
# 216           20       RL         65.0     8450   Pave   NaN      Reg
# 970           50       RL         60.0    10800   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 880          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 605          Lvl    AllPub    Inside  ...         189        0    NaN   NaN
# 1166         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 216          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 970          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 880          NaN       0       6    2007        WD         Normal
# 605          NaN       0      10    2009        WD         Normal
# 1166         NaN       0       2    2010        WD         Normal
# 216          NaN       0       4    2008        WD         Normal
# 970          NaN       0      12    2006        WD        Abnorml
#
# [5 rows x 79 columns]

# %%
ytest.head()
# Out:
# 880     157000
# 605     205000
# 1166    245350
# 216     210000
# 970     135000
# Name: SalePrice, dtype: int64

# %% [markdown]
# # Step 5 - Apply Preprocessing on xtrain, xtest

# %%
cat_cols = X.select_dtypes(include="object").columns.tolist()
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
num_cols = X.select_dtypes(include="number").columns.tolist()
num_cols
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(SimpleImputer(strategy="median"), StandardScaler())

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
    StandardScaler(),
)

# %%
pre = ColumnTransformer(
    [("num", num_pipe, num_cols), 
     ("cat", cat_pipe, cat_cols)],remainder="drop"
).set_output(transform="pandas")

# %%
pre.fit(xtrain)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea'...
#                                  ['MSZoning', 'Street', 'Alley', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
#                                   'RoofStyle', 'RoofMatl', 'Exterior1st',
#                                   'Exterior2nd', 'MasVnrType', 'ExterQual',
#                                   'ExterCond', 'Foundation', 'BsmtQual',
#                                   'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Heating', 'HeatingQC',
#                                   'CentralAir', 'Electrical', ...])])

# %%
xtrain_pre = pre.transform(xtrain)
xtrain_pre.head()
# Out:
#       num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 710         -0.639505         -0.640097     -0.610390         -2.264159
# 1098        -0.166757         -0.906459     -0.437322         -1.536438
# 1286        -0.875879         -0.018586     -0.086559         -0.080996
# 992          0.069617          0.425350     -0.089336         -0.080996
# 631          1.487861         -1.616757     -0.567817          1.374445
#
#       num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 710           0.371687       -1.182858           0.877919        -0.580525
# 1098          0.371687       -1.150075          -1.703259        -0.580525
# 1286         -0.521585       -0.264931          -1.070140         1.882760
# 992           2.158232       -0.232148           0.390904         1.276497
# 631          -0.521585        1.144742           1.024023         0.009352
#
#       num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  \
# 710         -0.968830        -0.274742  ...        -0.688303
# 1098         0.496747        -0.274742  ...         1.589141
# 1286         0.272112         0.229492  ...        -0.688303
# 992          0.200142         0.453597  ...        -0.688303
# 631         -0.916488        -0.274742  ...        -0.688303
#
#       cat__GarageFinish  cat__GarageQual  cat__GarageCond  cat__PavedDrive  \
# 710             0.95057         0.208601         0.189389        -3.520289
# 1098            0.95057         0.208601         0.189389         0.306326
# 1286            0.95057         0.208601         0.189389         0.306326
# 992            -0.27760         0.208601         0.189389         0.306326
# 631            -0.27760         0.208601         0.189389         0.306326
#
#       cat__PoolQC  cat__Fence  cat__MiscFeature  cat__SaleType  \
# 710      0.048825    0.244155          0.044155       0.308409
# 1098     0.048825    0.244155          0.044155       0.308409
# 1286     0.048825    0.244155          0.044155       0.308409
# 992      0.048825    2.543938          0.044155       0.308409
# 631      0.048825    0.244155          0.044155       0.308409
#
#       cat__SaleCondition
# 710             0.200871
# 1098            0.200871
# 1286            0.200871
# 992             0.200871
# 631             0.200871
#
# [5 rows x 79 columns]

# %%
xtest_pre = pre.transform(xtest)
xtest_pre.head()
# Out:
#       num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 880         -0.875879         -0.462522     -0.342552         -0.808717
# 605          0.069617          0.647318      0.266055          0.646725
# 1166        -0.875879         -0.284948     -0.023163          1.374445
# 216         -0.875879         -0.240554     -0.210576          0.646725
# 970         -0.166757         -0.462522      0.006916         -1.536438
#
#       num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 880          -0.521585        1.111959           1.024023        -0.580525
# 605           0.371687       -0.199365           0.244800         0.380757
# 1166         -0.521585        1.210308           1.121426        -0.187273
# 216          -0.521585        1.079176           0.926620         0.872322
# 970          -1.414858       -0.723895          -1.703259        -0.580525
#
#       num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  \
# 880          1.168470        -0.274742  ...        -0.688303
# 605          0.021307        -0.274742  ...        -0.688303
# 1166        -0.968830        -0.274742  ...        -0.688303
# 216          1.094318        -0.274742  ...        -0.688303
# 970         -0.968830        -0.274742  ...        -0.688303
#
#       cat__GarageFinish  cat__GarageQual  cat__GarageCond  cat__PavedDrive  \
# 880           -1.505771         0.208601         0.189389         0.306326
# 605            0.950570         0.208601         0.189389         0.306326
# 1166          -0.277600         0.208601         0.189389         0.306326
# 216            0.950570         0.208601         0.189389         0.306326
# 970            0.950570         0.208601         0.189389         0.306326
#
#       cat__PoolQC  cat__Fence  cat__MiscFeature  cat__SaleType  \
# 880      0.048825    0.244155          0.044155       0.308409
# 605      0.048825    0.244155          0.044155       0.308409
# 1166     0.048825    0.244155          0.044155       0.308409
# 216      0.048825    0.244155          0.044155       0.308409
# 970      0.048825    0.244155          0.044155       0.308409
#
#       cat__SaleCondition
# 880             0.200871
# 605             0.200871
# 1166            0.200871
# 216             0.200871
# 970            -3.508497
#
# [5 rows x 79 columns]

# %% [markdown]
# # Step 6 : Without feature slection model performance

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
score1 = cross_val_score(model1, xtrain_pre, ytrain, cv=5,scoring="r2")
score1
# Out:
# array([0.45776825, 0.76869615, 0.87768136, 0.83247963, 0.8379433 ])

# %%
score1.mean()
# Out:
# np.float64(0.7549137372810077)

# %%
score1.std()
# Out:
# np.float64(0.15262218701428132)

# %%
model1.fit(xtrain_pre, ytrain)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([ -4234.19547027,  -4407.43428242,   4884.73341086,  13573.52901554,
#          5910.51620103,   6754.9771549 ,    229.69980385,   7048.44041206,
#          2156.56229842,   1088.16771344,  -1698.5013599 ,    951.04562383,
#         10648.29841876,   8994.11027262,  -1293.6740205 ,  15191.05653263,
#          3814.87930081,  -1477.98375676,    862.06608963,   -866.75937464,
#         -3089.77687469,  -3602.34385035,   5817.7145369 ,   1654.13725966,
#           603.94490034,   8698.41798156,  -2629.17378393,   2567.4056948 ,
#           813.17284987,   -636.34469207,   1180.31552576,   3013.86829124,
#         -7228.14231174,  -2124.17826999,    471.93585824,  -1084.51920727,
#          -641.94916897,   2620.3599612 ,   -538.3399919 ,  -1424.83344029,
#          1485.32219047,  -1390.14117759,    635.25251899,   1726.84154495,
#          1417.72913285,   -932.63765494,   -263.42547965,  -3625.19966857,
#         -1022.71256917,   2835.27862448,   2375.89101669,  -3718.35544343,
#          2411.11155676,   4473.77139759,  -7012.71260949,    582.97755959,
#           -75.11752672,  -7531.70203738,   1095.30801433,  -4329.9962111 ,
#          -512.11327553,    886.55386009,   -566.06621993,   -719.31963929,
#          -364.54126301,   -500.06934891,  -5460.09251051,   4766.52679942,
#            56.95952205,   -108.66962993,   -812.54316191,   -542.67253995,
#           957.30775807,   1330.95868378, -10734.25377491,    -51.89078527,
#         -1941.33056514,  -1326.81303518,   2963.12718292])

# %%
model1.intercept_
# Out:
# np.float64(181136.7020547945)

# %%
train_r2 = model1.score(xtrain_pre, ytrain)
print(f"R2 score on train : {train_r2:.2%}")
# Out:
# R2 score on train : 86.80%

# %%
test_r2 = model1.score(xtest_pre, ytest)
test_r2
print(f"R2 score in test : {test_r2:.2%}")
# Out:
# R2 score in test : 79.98%

# %%
gen_error = abs(train_r2 - test_r2)
print(f"Generalization Error : {gen_error:.4f}")
# Out:
# Generalization Error : 0.0682

# %%
def evaluate_single_model(model, xtrain, ytrain, xtest, ytest):
    scores = cross_val_score(model, xtrain, ytrain, cv=5, scoring="r2")
    cv_mean = scores.mean().round(4)
    cv_std = scores.std().round(4)
    model.fit(xtrain, ytrain)
    train_r2 = round(model.score(xtrain, ytrain), 4)
    test_r2 = round(model.score(xtest, ytest), 4)
    gen_err = round(abs(train_r2 - test_r2), 4)
    return {
        "model_name": type(model).__name__,
        "model": model,
        "cv_mean": cv_mean,
        "cv_std": cv_std,
        "train_r2": train_r2,
        "test_r2": test_r2,
        "gen_err": gen_err,
    }

# %%
# Create a blank result list
results = []

# %%
r1 = evaluate_single_model(model1, xtrain_pre, ytrain, xtest_pre, ytest)
results.append(r1)
print(r1) # results list is created to store diff model results
# Out:
# {'model_name': 'LinearRegression', 'model': LinearRegression(), 'cv_mean': np.float64(0.7549), 'cv_std': np.float64(0.1526), 'train_r2': 0.868, 'test_r2': 0.7998, 'gen_err': 0.0682}

# %%
results
# Out:
# [{'model_name': 'LinearRegression',
#   'model': LinearRegression(),
#   'cv_mean': np.float64(0.7549),
#   'cv_std': np.float64(0.1526),
#   'train_r2': 0.868,
#   'test_r2': 0.7998,
#   'gen_err': 0.0682}]

# %% [markdown]
# # Feature selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector

base_model = LinearRegression()
sel = SequentialFeatureSelector(
    base_model, n_features_to_select="auto", direction="forward"
).set_output(transform="pandas")
sel.fit(xtrain_pre, ytrain)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression())

# %%
sel_cols = sel.get_feature_names_out()
print(sel_cols)
# Out:
# ['num__MSSubClass' 'num__LotArea' 'num__OverallQual' 'num__OverallCond'
#  'num__YearBuilt' 'num__MasVnrArea' 'num__BsmtFinSF2' 'num__GrLivArea'
#  'num__BsmtFullBath' 'num__BsmtHalfBath' 'num__KitchenAbvGr'
#  'num__Fireplaces' 'num__GarageCars' 'num__WoodDeckSF'
#  'num__EnclosedPorch' 'num__ScreenPorch' 'num__PoolArea' 'num__YrSold'
#  'cat__MSZoning' 'cat__Street' 'cat__Alley' 'cat__Utilities'
#  'cat__Neighborhood' 'cat__Condition2' 'cat__RoofStyle' 'cat__RoofMatl'
#  'cat__Exterior1st' 'cat__MasVnrType' 'cat__ExterQual' 'cat__BsmtQual'
#  'cat__BsmtCond' 'cat__BsmtExposure' 'cat__BsmtFinType1' 'cat__Heating'
#  'cat__KitchenQual' 'cat__Functional' 'cat__GarageFinish'
#  'cat__GarageCond' 'cat__SaleCondition']

# %%
len(sel_cols)
# Out:
# 39

# %%
xtrain_pre_sel = sel.transform(xtrain_pre)
xtrain_pre_sel.head()
# Out:
#       num__MSSubClass  num__LotArea  num__OverallQual  num__OverallCond  \
# 710         -0.639505     -0.610390         -2.264159          0.371687
# 1098        -0.166757     -0.437322         -1.536438          0.371687
# 1286        -0.875879     -0.086559         -0.080996         -0.521585
# 992          0.069617     -0.089336         -0.080996          2.158232
# 631          1.487861     -0.567817          1.374445         -0.521585
#
#       num__YearBuilt  num__MasVnrArea  num__BsmtFinSF2  num__GrLivArea  \
# 710        -1.182858        -0.580525        -0.274742       -1.511625
# 1098       -1.150075        -0.580525        -0.274742       -0.373855
# 1286       -0.264931         1.882760         0.229492       -0.366206
# 992        -0.232148         1.276497         0.453597        0.633884
# 631         1.144742         0.009352        -0.274742        0.065955
#
#       num__BsmtFullBath  num__BsmtHalfBath  ...  cat__BsmtQual  cat__BsmtCond  \
# 710           -0.807777          -0.237226  ...       0.832542       0.280382
# 1098          -0.807777          -0.237226  ...       0.832542       0.280382
# 1286           1.105982          -0.237226  ...       0.832542       0.280382
# 992           -0.807777          -0.237226  ...       0.832542       0.280382
# 631           -0.807777          -0.237226  ...      -0.347566      -2.766001
#
#       cat__BsmtExposure  cat__BsmtFinType1  cat__Heating  cat__KitchenQual  \
# 710            0.642826           1.276335     -0.120232          0.807064
# 1098           0.642826          -0.962042     -0.120232          0.807064
# 1286           0.642826          -1.521637     -0.120232          0.807064
# 992           -1.089171          -0.962042     -0.120232         -0.412407
# 631           -0.223173          -0.402448     -0.120232         -0.412407
#
#       cat__Functional  cat__GarageFinish  cat__GarageCond  cat__SaleCondition
# 710         -5.028120            0.95057         0.189389            0.200871
# 1098         0.253215            0.95057         0.189389            0.200871
# 1286         0.253215            0.95057         0.189389            0.200871
# 992          0.253215           -0.27760         0.189389            0.200871
# 631          0.253215           -0.27760         0.189389            0.200871
#
# [5 rows x 39 columns]

# %%
xtest_pre_sel = sel.transform(xtest_pre)
xtest_pre_sel.head()
# Out:
#       num__MSSubClass  num__LotArea  num__OverallQual  num__OverallCond  \
# 880         -0.875879     -0.342552         -0.808717         -0.521585
# 605          0.069617      0.266055          0.646725          0.371687
# 1166        -0.875879     -0.023163          1.374445         -0.521585
# 216         -0.875879     -0.210576          0.646725         -0.521585
# 970         -0.166757      0.006916         -1.536438         -1.414858
#
#       num__YearBuilt  num__MasVnrArea  num__BsmtFinSF2  num__GrLivArea  \
# 880         1.111959        -0.580525        -0.274742       -0.821314
# 605        -0.199365         0.380757        -0.274742        0.892034
# 1166        1.210308        -0.187273        -0.274742        0.333666
# 216         1.079176         0.872322        -0.274742       -0.159687
# 970        -0.723895        -0.580525        -0.274742       -0.626268
#
#       num__BsmtFullBath  num__BsmtHalfBath  ...  cat__BsmtQual  cat__BsmtCond  \
# 880            1.105982          -0.237226  ...      -2.707784      -2.766001
# 605           -0.807777          -0.237226  ...       0.832542       0.280382
# 1166          -0.807777          -0.237226  ...      -0.347566       0.280382
# 216            1.105982          -0.237226  ...      -0.347566       0.280382
# 970           -0.807777          -0.237226  ...       0.832542       0.280382
#
#       cat__BsmtExposure  cat__BsmtFinType1  cat__Heating  cat__KitchenQual  \
# 880            0.642826          -1.521637     -0.120232          0.807064
# 605            0.642826          -0.962042     -0.120232          0.807064
# 1166          -1.955169           1.276335     -0.120232         -0.412407
# 216           -0.223173          -0.402448     -0.120232         -0.412407
# 970            0.642826           1.276335     -0.120232          0.807064
#
#       cat__Functional  cat__GarageFinish  cat__GarageCond  cat__SaleCondition
# 880          0.253215          -1.505771         0.189389            0.200871
# 605          0.253215           0.950570         0.189389            0.200871
# 1166         0.253215          -0.277600         0.189389            0.200871
# 216          0.253215           0.950570         0.189389            0.200871
# 970          0.253215           0.950570         0.189389           -3.508497
#
# [5 rows x 39 columns]

# %%
model2 = LinearRegression()
r2 = evaluate_single_model(model2, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest)
results.append(r2)
print(r2)
# Out:
# {'model_name': 'LinearRegression', 'model': LinearRegression(), 'cv_mean': np.float64(0.8383), 'cv_std': np.float64(0.08), 'train_r2': 0.8525, 'test_r2': 0.8019, 'gen_err': 0.0506}

# %%
results
# Out:
# [{'model_name': 'LinearRegression',
#   'model': LinearRegression(),
#   'cv_mean': np.float64(0.7549),
#   'cv_std': np.float64(0.1526),
#   'train_r2': 0.868,
#   'test_r2': 0.7998,
#   'gen_err': 0.0682},
#  {'model_name': 'LinearRegression',
#   'model': LinearRegression(),
#   'cv_mean': np.float64(0.8383),
#   'cv_std': np.float64(0.08),
#   'train_r2': 0.8525,
#   'test_r2': 0.8019,
#   'gen_err': 0.0506}]

# %% [markdown]
# # Build Ridge and Lasso models

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=1)
rr.fit(xtrain_pre_sel, ytrain)
# Out:
# Ridge(alpha=1)

# %%
params = {"alpha": [0.1, 0.5, 1, 10, 50, 100, 500, 1000]}

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge_base = Ridge(random_state=42)
gscv_ridge = GridSearchCV(ridge_base, params,  cv=5,scoring="r2")
gscv_ridge.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(random_state=42),
#              param_grid={'alpha': [0.1, 0.5, 1, 10, 50, 100, 500, 1000]},
#              scoring='r2')

# %%
gscv_ridge.best_params_
# Out:
# {'alpha': 50}

# %%
best_ridge = gscv_ridge.best_estimator_
best_ridge
# Out:
# Ridge(alpha=50, random_state=42)

# %%
gscv_ridge.best_score_
# Out:
# np.float64(0.839327799002602)

# %%
r3 = evaluate_single_model(best_ridge, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest)
results.append(r3)
print(r3)
# Out:
# {'model_name': 'Ridge', 'model': Ridge(alpha=50, random_state=42), 'cv_mean': np.float64(0.8393), 'cv_std': np.float64(0.0755), 'train_r2': 0.8521, 'test_r2': 0.8051, 'gen_err': 0.047}

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso

lasso_base = Lasso(random_state=42)
gscv_lasso = GridSearchCV(lasso_base, params, scoring="r2", cv=5)
gscv_lasso.fit(xtrain_pre_sel, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(random_state=42),
#              param_grid={'alpha': [0.1, 0.5, 1, 10, 50, 100, 500, 1000]},
#              scoring='r2')

# %%
gscv_lasso.best_params_
# Out:
# {'alpha': 0.1}

# %%
gscv_lasso.best_score_
# Out:
# np.float64(0.8382539331903759)

# %%
best_lasso = gscv_lasso.best_estimator_
best_lasso
# Out:
# Lasso(alpha=0.1, random_state=42)

# %%
r = evaluate_single_model(best_lasso, xtrain_pre_sel, ytrain, xtest_pre_sel, ytest)
print(r)
results.append(r)
# Out:
# {'model_name': 'Lasso', 'model': Lasso(alpha=0.1, random_state=42), 'cv_mean': np.float64(0.8383), 'cv_std': np.float64(0.08), 'train_r2': 0.8525, 'test_r2': 0.8019, 'gen_err': 0.0506}

# %%
results
# Out:
# [{'model_name': 'LinearRegression',
#   'model': LinearRegression(),
#   'cv_mean': np.float64(0.7549),
#   'cv_std': np.float64(0.1526),
#   'train_r2': 0.868,
#   'test_r2': 0.7998,
#   'gen_err': 0.0682},
#  {'model_name': 'LinearRegression',
#   'model': LinearRegression(),
#   'cv_mean': np.float64(0.8383),
#   'cv_std': np.float64(0.08),
#   'train_r2': 0.8525,
#   'test_r2': 0.8019,
#   'gen_err': 0.0506},
#  {'model_name': 'Ridge',
#   'model': Ridge(alpha=50, random_state=42),
#   'cv_mean': np.float64(0.8393),
#   'cv_std': np.float64(0.0755),
#   'train_r2': 0.8521,
#   'test_r2': 0.8051,
#   'gen_err': 0.047},
#  {'model_name': 'Ridge',
#   'model': Ridge(alpha=50, random_state=42),
#   'cv_mean': np.float64(0.8393),
#   'cv_std': np.float64(0.0755),
#   'train_r2': 0.8521,
#   'test_r2': 0.8051,
#   'gen_err': 0.047}]

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#          model_name                             model  cv_mean  cv_std  \
# 0  LinearRegression                LinearRegression()   0.7549  0.1526
# 1  LinearRegression                LinearRegression()   0.8383  0.0800
# 2             Ridge  Ridge(alpha=50, random_state=42)   0.8393  0.0755
# 3             Ridge  Ridge(alpha=50, random_state=42)   0.8393  0.0755
#
#    train_r2  test_r2  gen_err
# 0    0.8680   0.7998   0.0682
# 1    0.8525   0.8019   0.0506
# 2    0.8521   0.8051   0.0470
# 3    0.8521   0.8051   0.0470

# %%
sort_df = results_df.sort_values(by="cv_mean", ascending=False).reset_index(drop=True)
sort_df
# Out:
#          model_name                             model  cv_mean  cv_std  \
# 0             Ridge  Ridge(alpha=50, random_state=42)   0.8393  0.0755
# 1             Ridge  Ridge(alpha=50, random_state=42)   0.8393  0.0755
# 2  LinearRegression                LinearRegression()   0.8383  0.0800
# 3  LinearRegression                LinearRegression()   0.7549  0.1526
#
#    train_r2  test_r2  gen_err
# 0    0.8521   0.8051   0.0470
# 1    0.8521   0.8051   0.0470
# 2    0.8525   0.8019   0.0506
# 3    0.8680   0.7998   0.0682

# %%
# Polynomial features will add square, cube or other terms
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False).set_output(transform="pandas")
poly.fit_transform(xtrain_pre_sel)
# Out:
#       num__MSSubClass  num__LotArea  num__OverallQual  num__OverallCond  \
# 710         -0.639505     -0.610390         -2.264159          0.371687
# 1098        -0.166757     -0.437322         -1.536438          0.371687
# 1286        -0.875879     -0.086559         -0.080996         -0.521585
# 992          0.069617     -0.089336         -0.080996          2.158232
# 631          1.487861     -0.567817          1.374445         -0.521585
# ...               ...           ...               ...               ...
# 368         -0.875879     -0.270733         -0.808717          0.371687
# 48           3.142478     -0.580219         -1.536438         -0.521585
# 772          0.542365     -0.268975         -0.080996         -0.521585
# 1231         0.778739     -0.277397         -0.808717          0.371687
# 969          3.142478     -0.031770         -0.080996         -0.521585
#
#       num__YearBuilt  num__MasVnrArea  num__BsmtFinSF2  num__GrLivArea  \
# 710        -1.182858        -0.580525        -0.274742       -1.511625
# 1098       -1.150075        -0.580525        -0.274742       -0.373855
# 1286       -0.264931         1.882760         0.229492       -0.366206
# 992        -0.232148         1.276497         0.453597        0.633884
# 631         1.144742         0.009352        -0.274742        0.065955
# ...              ...              ...              ...             ...
# 368        -0.559979         0.511841        -0.274742       -0.480939
# 48         -1.674604        -0.580525        -0.274742       -0.129091
# 772         0.161249        -0.580525         0.515848       -0.769684
# 1231       -0.297714         0.074894        -0.274742       -0.630092
# 969        -0.428847        -0.007033        -0.274742       -0.811753
#
#       num__BsmtFullBath  num__BsmtHalfBath  ...  cat__Functional^2  \
# 710           -0.807777          -0.237226  ...          25.281987
# 1098          -0.807777          -0.237226  ...           0.064118
# 1286           1.105982          -0.237226  ...           0.064118
# 992           -0.807777          -0.237226  ...           0.064118
# 631           -0.807777          -0.237226  ...           0.064118
# ...                 ...                ...  ...                ...
# 368           -0.807777          -0.237226  ...           0.064118
# 48            -0.807777          -0.237226  ...           0.064118
# 772            1.105982          -0.237226  ...           0.064118
# 1231           1.105982          -0.237226  ...           0.064118
# 969            1.105982          -0.237226  ...           0.064118
#
#       cat__Functional cat__GarageFinish  cat__Functional cat__GarageCond  \
# 710                           -4.779582                        -0.952271
# 1098                           0.240698                         0.047956
# 1286                           0.240698                         0.047956
# 992                           -0.070292                         0.047956
# 631                           -0.070292                         0.047956
# ...                                 ...                              ...
# 368                           -0.381283                         0.047956
# 48                             0.240698                         0.047956
# 772                            0.240698                         0.047956
# 1231                           0.240698                         0.047956
# 969                           -0.070292                         0.047956
#
#       cat__Functional cat__SaleCondition  cat__GarageFinish^2  \
# 710                            -1.010004             0.903584
# 1098                            0.050864             0.903584
# 1286                            0.050864             0.903584
# 992                             0.050864             0.077062
# 631                             0.050864             0.077062
# ...                                  ...                  ...
# 368                             0.050864             2.267346
# 48                              0.285680             0.903584
# 772                            -0.888403             0.903584
# 1231                            0.050864             0.903584
# 969                             0.050864             0.077062
#
#       cat__GarageFinish cat__GarageCond  cat__GarageFinish cat__SaleCondition  \
# 710                            0.180028                              0.190942
# 1098                           0.180028                              0.190942
# 1286                           0.180028                              0.190942
# 992                           -0.052574                             -0.055762
# 631                           -0.052574                             -0.055762
# ...                                 ...                                   ...
# 368                           -0.285176                             -0.302466
# 48                             0.180028                              1.072446
# 772                            0.180028                             -3.335073
# 1231                           0.180028                              0.190942
# 969                           -0.052574                             -0.055762
#
#       cat__GarageCond^2  cat__GarageCond cat__SaleCondition  \
# 710            0.035868                            0.038043
# 1098           0.035868                            0.038043
# 1286           0.035868                            0.038043
# 992            0.035868                            0.038043
# 631            0.035868                            0.038043
# ...                 ...                                 ...
# 368            0.035868                            0.038043
# 48             0.035868                            0.213671
# 772            0.035868                           -0.664471
# 1231           0.035868                            0.038043
# 969            0.035868                            0.038043
#
#       cat__SaleCondition^2
# 710               0.040349
# 1098              0.040349
# 1286              0.040349
# 992               0.040349
# 631               0.040349
# ...                    ...
# 368               0.040349
# 48                1.272865
# 772              12.309549
# 1231              0.040349
# 969               0.040349
#
# [1168 rows x 819 columns]

# %%
best_final_model = sort_df.loc[0, "model"]
best_final_model
# Out:
# Ridge(alpha=50, random_state=42)

# %%
sort_df.to_csv("evaluation.csv", index=False)

# %%
# Evaluate Selected model in detail

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score,
)


def eval_model(model, x, y):
    ypred = model.predict(x)
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2%}")
    print(f"R2 : {r2:.2%}")

# %%
print("Ridge Model Training Results")
eval_model(best_final_model, xtrain_pre_sel, ytrain)
# Out:
# Ridge Model Training Results
# RMSE : 30256.92
# MAE : 18745.82
# MAPE : 10.94%
# R2 : 85.21%

# %%
print("Ridge Model Testing Results")
eval_model(best_final_model, xtest_pre_sel, ytest)
# Out:
# Ridge Model Testing Results
# RMSE : 36340.98
# MAE : 19499.66
# MAPE : 10.96%
# R2 : 80.51%

# %% [markdown]
# # Because r2 score in train and test is more than 80% both in train and test hence it is a good model
# # Out of Sample Prediction

# %%
xnew = pd.read_csv("testing_set.csv")
xnew.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea'...
#                                  ['MSZoning', 'Street', 'Alley', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
#                                   'RoofStyle', 'RoofMatl', 'Exterior1st',
#                                   'Exterior2nd', 'MasVnrType', 'ExterQual',
#                                   'ExterCond', 'Foundation', 'BsmtQual',
#                                   'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Heating', 'HeatingQC',
#                                   'CentralAir', 'Electrical', ...])])

# %%
sel
# Out:
# SequentialFeatureSelector(estimator=LinearRegression())

# %%
xnew_pre = pre.transform(xnew)
xnew_pre.head()
# Out:
#    num__MSSubClass  num__LotFrontage  num__LotArea  num__OverallQual  \
# 0        -0.875879          0.425350      0.082992         -0.808717
# 1        -0.875879          0.469744      0.327786         -0.080996
# 2         0.069617          0.158989      0.287342         -0.808717
# 3         0.069617          0.336563     -0.069160         -0.080996
# 4         1.487861         -1.217214     -0.529409          1.374445
#
#    num__OverallCond  num__YearBuilt  num__YearRemodAdd  num__MasVnrArea  \
# 0          0.371687       -0.330497          -1.167543        -0.580525
# 1          0.371687       -0.428847          -1.313647         0.009352
# 2         -0.521585        0.849694           0.634412        -0.580525
# 3          0.371687        0.882477           0.634412        -0.471289
# 4         -0.521585        0.685779           0.342203        -0.580525
#
#    num__BsmtFinSF1  num__BsmtFinSF2  ...  cat__GarageType  cat__GarageFinish  \
# 0         0.051840         0.621675  ...        -0.688303           0.950570
# 1         1.044157        -0.274742  ...        -0.688303           0.950570
# 2         0.756276        -0.274742  ...        -0.688303          -1.505771
# 3         0.344083        -0.274742  ...        -0.688303          -1.505771
# 4        -0.395248        -0.274742  ...        -0.688303          -0.277600
#
#    cat__GarageQual  cat__GarageCond  cat__PavedDrive  cat__PoolQC  cat__Fence  \
# 0         0.208601         0.189389         0.306326     0.048825    0.244155
# 1         0.208601         0.189389         0.306326     0.048825    0.244155
# 2         0.208601         0.189389         0.306326     0.048825    0.244155
# 3         0.208601         0.189389         0.306326     0.048825    0.244155
# 4         0.208601         0.189389         0.306326     0.048825    0.244155
#
#    cat__MiscFeature  cat__SaleType  cat__SaleCondition
# 0          0.044155       0.308409            0.200871
# 1        -20.584838       0.308409            0.200871
# 2          0.044155       0.308409            0.200871
# 3          0.044155       0.308409            0.200871
# 4          0.044155       0.308409            0.200871
#
# [5 rows x 79 columns]

# %%
xnew_pre_sel = sel.transform(xnew_pre)
xnew_pre_sel.head()
# Out:
#    num__MSSubClass  num__LotArea  num__OverallQual  num__OverallCond  \
# 0        -0.875879      0.082992         -0.808717          0.371687
# 1        -0.875879      0.327786         -0.080996          0.371687
# 2         0.069617      0.287342         -0.808717         -0.521585
# 3         0.069617     -0.069160         -0.080996          0.371687
# 4         1.487861     -0.529409          1.374445         -0.521585
#
#    num__YearBuilt  num__MasVnrArea  num__BsmtFinSF2  num__GrLivArea  \
# 0       -0.330497        -0.580525         0.621675       -1.192285
# 1       -0.428847         0.009352        -0.274742       -0.364294
# 2        0.849694        -0.580525        -0.274742        0.209372
# 3        0.882477        -0.471289        -0.274742        0.161566
# 4        0.685779        -0.580525        -0.274742       -0.457993
#
#    num__BsmtFullBath  num__BsmtHalfBath  ...  cat__BsmtQual  cat__BsmtCond  \
# 0          -0.807777          -0.237226  ...       0.832542       0.280382
# 1          -0.807777          -0.237226  ...       0.832542       0.280382
# 2          -0.807777          -0.237226  ...      -0.347566       0.280382
# 3          -0.807777          -0.237226  ...       0.832542       0.280382
# 4          -0.807777          -0.237226  ...      -0.347566       0.280382
#
#    cat__BsmtExposure  cat__BsmtFinType1  cat__Heating  cat__KitchenQual  \
# 0           0.642826           0.716741     -0.120232          0.807064
# 1           0.642826          -1.521637     -0.120232         -0.412407
# 2           0.642826          -0.402448     -0.120232          0.807064
# 3           0.642826          -0.402448     -0.120232         -0.412407
# 4           0.642826          -1.521637     -0.120232         -0.412407
#
#    cat__Functional  cat__GarageFinish  cat__GarageCond  cat__SaleCondition
# 0         0.253215           0.950570         0.189389            0.200871
# 1         0.253215           0.950570         0.189389            0.200871
# 2         0.253215          -1.505771         0.189389            0.200871
# 3         0.253215          -1.505771         0.189389            0.200871
# 4         0.253215          -0.277600         0.189389            0.200871
#
# [5 rows x 39 columns]

# %%
preds = best_final_model.predict(xnew_pre_sel)
preds[0:5]
# Out:
# array([108550.42370094, 156311.54095453, 167380.76650828, 174224.96974414,
#        191090.74612421])

# %%
import seaborn as sns

sns.histplot(preds, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
res = xnew[["Id"]]
res.head()
# Out:
#      Id
# 0  1461
# 1  1462
# 2  1463
# 3  1464
# 4  1465

# %%
res["SalePrice"] = preds.round(2)
res
# Out:
#         Id  SalePrice
# 0     1461  108550.42
# 1     1462  156311.54
# 2     1463  167380.77
# 3     1464  174224.97
# 4     1465  191090.75
# ...    ...        ...
# 1454  2915   70814.87
# 1455  2916   66133.69
# 1456  2917  158470.83
# 1457  2918  112565.32
# 1458  2919  229600.49
#
# [1459 rows x 2 columns]

# %%
res.to_csv("results.csv", index=False)

# %% [markdown]
# # Save the model object, preprocessor and selectore

# %%
import joblib

joblib.dump(pre, "pre.joblib")
# Out:
# ['pre.joblib']

# %%
joblib.dump(sel, "sel.joblib")
# Out:
# ['sel.joblib']

# %%
joblib.dump(best_final_model, "ridge_price_model.joblib")
# Out:
# ['ridge_price_model.joblib']

# %% [markdown]
# # Load the files

# %%
p = joblib.load("pre.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea'...
#                                  ['MSZoning', 'Street', 'Alley', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
#                                   'RoofStyle', 'RoofMatl', 'Exterior1st',
#                                   'Exterior2nd', 'MasVnrType', 'ExterQual',
#                                   'ExterCond', 'Foundation', 'BsmtQual',
#                                   'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Heating', 'HeatingQC',
#                                   'CentralAir', 'Electrical', ...])])

# %%
sel = joblib.load("sel.joblib")
sel
# Out:
# SequentialFeatureSelector(estimator=LinearRegression())

# %%
m = joblib.load("ridge_price_model.joblib")
m
# Out:
# Ridge(alpha=50, random_state=42)

# %%
m.score(xtrain_pre_sel, ytrain)
# Out:
# 0.8520775435989794

# %%
m.score(xtest_pre_sel, ytest)
# Out:
# 0.8051340907228183
