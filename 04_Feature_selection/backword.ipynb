# %% [markdown]
# # Backward Feature Selection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings

filterwarnings("ignore")

# %% [markdown]
# # Step 1 - Data ingestion

# %%
import pandas as pd

df = pd.read_csv("Cars93.csv", na_values=["", "NA"], keep_default_na=False)
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
#    Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# 0           37            26.5         11.0    2705  non-USA  Acura Integra
# 1           38            30.0         15.0    3560  non-USA   Acura Legend
# 2           37            28.0         14.0    3375  non-USA        Audi 90
# 3           37            31.0         17.0    3405  non-USA       Audi 100
# 4           39            27.0         13.0    3640  non-USA       BMW 535i
#
# [5 rows x 28 columns]

# %% [markdown]
# # Target - Weight
# Predict weight of cars based on other factors

# %% [markdown]
# # Step 2 - Perform basic data quality checks

# %%
df.shape
# Out:
# (94, 28)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df.shape
# Out:
# (93, 28)

# %%
m = df.isna().sum()
m[m > 0]
# Out:
# AirBags            4
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
# Cardinality is checked only on categorical features
df.select_dtypes(include="object").nunique()
# Out:
# Manufacturer       32
# Model              93
# Type                6
# AirBags             3
# DriveTrain          3
# Cylinders           6
# Man.trans.avail     2
# Origin              2
# Make               93
# dtype: int64

# %%
len(df)
# Out:
# 93

# %%
def get_high_card(df, threshold=0.9):
    cat_unique = df.select_dtypes(include="object").nunique()
    rows = len(df)
    cardinality = cat_unique / rows
    high_card = cardinality[cardinality >= threshold]
    print(high_card)
    return high_card.index.tolist()

# %%
high_card = get_high_card(df, threshold=0.9)
print(high_card)
# Out:
# Model    1.0
# Make     1.0
# dtype: float64
# ['Model', 'Make']

# %%
df = df.drop(columns=high_card)
df.shape
# Out:
# (93, 26)

# %%
df.head()
# Out:
#    id Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura    Small       12.9   15.9       18.8        25
# 1   2        Acura  Midsize       29.2   33.9       38.7        18
# 2   3         Audi  Compact       25.9   29.1       32.3        20
# 3   4         Audi  Midsize       30.8   37.7       44.6        19
# 4   5          BMW  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0           31                None      Front  ...               13.2
# 1           25  Driver & Passenger      Front  ...               18.0
# 2           26         Driver only      Front  ...               16.9
# 3           26                 NaN      Front  ...               21.1
# 4           30         Driver only       Rear  ...               21.1
#
#    Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0           5     177        102     68          37            26.5
# 1           5     195        115     71          38            30.0
# 2           5     180        102     67          37            28.0
# 3           6     193        106     70          37            31.0
# 4           4     186        109     69          39            27.0
#
#    Luggage.room  Weight   Origin
# 0          11.0    2705  non-USA
# 1          15.0    3560  non-USA
# 2          14.0    3375  non-USA
# 3          17.0    3405  non-USA
# 4          13.0    3640  non-USA
#
# [5 rows x 26 columns]

# %% [markdown]
# # Step 3 - Seperate X and Y(Weight)

# %%
X = df.drop(columns=["id", "Weight"])
Y = df["Weight"]

# %%
X.head()
# Out:
#   Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0        Acura    Small       12.9   15.9       18.8        25           31
# 1        Acura  Midsize       29.2   33.9       38.7        18           25
# 2         Audi  Compact       25.9   29.1       32.3        20           26
# 3         Audi  Midsize       30.8   37.7       44.6        19           26
# 4          BMW  Midsize       23.7   30.0       36.2        22           30
#
#               AirBags DriveTrain Cylinders  ...  Man.trans.avail  \
# 0                None      Front         4  ...              Yes
# 1  Driver & Passenger      Front         6  ...              Yes
# 2         Driver only      Front         6  ...              Yes
# 3                 NaN      Front         6  ...              Yes
# 4         Driver only       Rear         4  ...              Yes
#
#    Fuel.tank.capacity  Passengers  Length Wheelbase  Width  Turn.circle  \
# 0                13.2           5     177       102     68           37
# 1                18.0           5     195       115     71           38
# 2                16.9           5     180       102     67           37
# 3                21.1           6     193       106     70           37
# 4                21.1           4     186       109     69           39
#
#    Rear.seat.room  Luggage.room   Origin
# 0            26.5          11.0  non-USA
# 1            30.0          15.0  non-USA
# 2            28.0          14.0  non-USA
# 3            31.0          17.0  non-USA
# 4            27.0          13.0  non-USA
#
# [5 rows x 24 columns]

# %%
Y.head()
# Out:
# 0    2705
# 1    3560
# 2    3375
# 3    3405
# 4    3640
# Name: Weight, dtype: int64

# %% [markdown]
# # Step 4 - Train Test Split
# test 0.2-0.4

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
xtrain.head()
# Out:
#    Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 42        Honda  Compact       13.8   17.5       21.2        24           31
# 53        Mazda    Small       10.9   11.6       12.3        28           36
# 21     Chrysler    Large       29.5   29.5       29.5        20           26
# 6         Buick    Large       19.9   20.8       21.7        19           28
# 26        Dodge  Midsize       14.8   15.6       16.4        21           27
#
#                AirBags DriveTrain Cylinders  ...  Man.trans.avail  \
# 42  Driver & Passenger      Front         4  ...              Yes
# 53                None      Front         4  ...              Yes
# 21                 NaN      Front         6  ...               No
# 6          Driver only      Front         6  ...               No
# 26         Driver only      Front         4  ...               No
#
#     Fuel.tank.capacity  Passengers  Length Wheelbase  Width  Turn.circle  \
# 42                17.0           4     185       107     67           41
# 53                14.5           5     172        98     66           36
# 21                16.0           6     203       110     69           44
# 6                 18.0           6     200       111     74           42
# 26                16.0           6     192       105     69           42
#
#     Rear.seat.room  Luggage.room   Origin
# 42            28.0          14.0  non-USA
# 53            26.5          13.0  non-USA
# 21            36.0          17.0      USA
# 6             30.5          17.0      USA
# 26            30.5          16.0      USA
#
# [5 rows x 24 columns]

# %%
ytrain.head()
# Out:
# 42    3040
# 53    2440
# 21    3570
# 6     3470
# 26    3080
# Name: Weight, dtype: int64

# %%
xtest.head()
# Out:
#    Manufacturer     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 34         Ford   Sporty       12.8   14.0       15.2        24           30
# 90   Volkswagen   Sporty       22.9   23.3       23.7        18           25
# 3          Audi  Midsize       30.8   37.7       44.6        19           26
# 35         Ford      Van       14.5   19.9       25.3        15           20
# 19     Chrylser    Large       18.4   18.4       18.4        20           28
#
#                AirBags DriveTrain Cylinders  ...  Man.trans.avail  \
# 34         Driver only      Front         4  ...              Yes
# 90                None      Front         6  ...              Yes
# 3                  NaN      Front         6  ...              Yes
# 35         Driver only        4WD         6  ...              Yes
# 19  Driver & Passenger      Front         6  ...               No
#
#     Fuel.tank.capacity  Passengers  Length Wheelbase  Width  Turn.circle  \
# 34                15.5           4     179       103     70           38
# 90                18.5           4     159        97     66           36
# 3                 21.1           6     193       106     70           37
# 35                21.0           7     176       119     72           45
# 19                18.0           6     203       113     74           40
#
#     Rear.seat.room  Luggage.room   Origin
# 34            23.0          18.0      USA
# 90            26.0          15.0  non-USA
# 3             31.0          17.0  non-USA
# 35            30.0           NaN      USA
# 19            31.0          15.0      USA
#
# [5 rows x 24 columns]

# %%
ytest.head()
# Out:
# 34    2710
# 90    2810
# 3     3405
# 35    3735
# 19    3515
# Name: Weight, dtype: int64

# %% [markdown]
# # Step 5 - Apply Preprocessing on xtrain, xtest

# %%
cat_cols = X.select_dtypes(include="object").columns.tolist()
cat_cols
# Out:
# ['Manufacturer',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %%
num_cols = X.select_dtypes(include="number").columns.tolist()
num_cols
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(SimpleImputer(strategy="median"), StandardScaler())

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
    StandardScaler(),
)

# %%
pre = ColumnTransformer(
    [("num", num_pipe, num_cols), ("cat", cat_pipe, cat_cols)]
).set_output(transform="pandas")

# %%
pre.fit(xtrain)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Min.Price', 'Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Manufacturer', 'Type', 'AirBags',
#                                   'DriveTrain', 'Cylinders', 'Man.trans.avail',
#                                   'Origin'])])

# %%
xtrain_pre = pre.transform(xtrain)
xtrain_pre.head()
# Out:
#     num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 42       -0.373824   -0.208643       -0.071922       0.318308
# 53       -0.699007   -0.802086       -0.851002       1.066078
# 21        1.386650    0.998360        0.654635      -0.429463
# 6         0.310182    0.123283       -0.028154      -0.616405
# 26       -0.261692   -0.399752       -0.492100      -0.242520
#
#     num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 42          0.363084        -0.499737        -0.070927  0.583333
# 53          1.322665        -0.871400        -0.759572  0.416667
# 21         -0.596496         0.522338         0.059357 -0.750000
# 6          -0.212664         0.986917         0.487434 -0.750000
# 26         -0.404580        -0.220989        -0.815408 -0.750000
#
#     num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 42           0.553885                 0.094849  ...          0.554316
# 53          -0.190474                -0.664766  ...         -0.987766
# 21          -1.020721                -0.208997  ...          1.479565
# 6           -1.431073                 0.398695  ...          0.862732
# 26           0.277136                -0.208997  ...          0.862732
#
#     num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 42             0.030727           0.028068          -0.330948  -1.373237
# 53            -0.456514          -0.318105           0.266373   0.474391
# 21             2.629344           1.066586          -0.928269  -0.757361
# 6              0.842795           1.066586          -1.286661  -0.757361
# 26             0.842795           0.720413          -0.808804  -0.141485
#
#     cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 42     -1.720536        -0.180439       -0.763650              0.780189
# 53      1.173093        -0.180439       -0.763650              0.780189
# 21     -0.273722        -0.180439        0.975122             -1.281740
# 6      -0.273722        -0.180439        0.975122             -1.281740
# 26     -0.273722        -0.180439       -0.763650             -1.281740
#
#     cat__Origin
# 42     1.114641
# 53     1.114641
# 21    -0.897150
# 6     -0.897150
# 26    -0.897150
#
# [5 rows x 24 columns]

# %%
xtest_pre = pre.transform(xtest)
xtest_pre.head()
# Out:
#     num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 34       -0.485956   -0.560685       -0.597145       0.318308
# 90        0.646578    0.374742        0.146920      -0.803348
# 3         1.532421    1.823145        1.976445      -0.616405
# 35       -0.295332    0.032758        0.286980      -1.364176
# 19        0.141983   -0.118118       -0.317026      -0.429463
#
#     num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 34          0.171168        -0.685568        -0.536227  0.416667
# 90         -0.788412         0.057759         0.636330  0.916667
# 3          -0.596496         0.057759         0.524658  0.416667
# 35         -1.747992         0.243590         0.022133 -0.750000
# 19         -0.212664         0.522338         0.171029  0.083333
#
#     num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 34           0.038559                -0.360920  ...         -0.370933
# 90           0.124447                 0.550618  ...         -0.987766
# 3            0.410739                 1.340618  ...         -0.679350
# 35          -0.457680                 1.310233  ...          1.787981
# 19          -0.629455                 0.398695  ...          0.245900
#
#     num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 34            -1.593409           1.412758          -0.569876   1.090267
# 90            -0.618927           0.374241           1.699942   1.090267
# 3              1.005208           1.066586          -1.525589  -0.141485
# 35             0.680381           0.028068          -0.569876   1.706143
# 19             1.005208           0.374241          -1.764517  -0.757361
#
#     cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 34     -0.273722        -0.180439       -0.763650              0.780189
# 90      1.173093        -0.180439        0.975122              0.780189
# 3      -0.273722        -0.180439        0.975122              0.780189
# 35     -0.273722        -2.087934        0.975122              0.780189
# 19     -1.720536        -0.180439        0.975122             -1.281740
#
#     cat__Origin
# 34    -0.897150
# 90     1.114641
# 3      1.114641
# 35    -0.897150
# 19    -0.897150
#
# [5 rows x 24 columns]

# %% [markdown]
# # Step 6 - Check base model performance

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(xtrain_pre, ytrain)
# Out:
# LinearRegression()

# %%
train_r2 = model.score(xtrain_pre, ytrain)
print(f"Train R2 : {train_r2:.4f}")
# Out:
# Train R2 : 0.9725

# %%
test_r2 = model.score(xtest_pre, ytest)
print(f"Test R2 : {test_r2:.4f}")
# Out:
# Test R2 : 0.8217

# %%
gen_error = abs(train_r2 - test_r2)
print(f"Generalization Error : {gen_error:.4f}")
# Out:
# Generalization Error : 0.1508

# %% [markdown]
# # Step 7 - Forward Feature selection
# one by one features are added in model

# %%
from sklearn.feature_selection import SequentialFeatureSelector

base_model = LinearRegression()
sel = SequentialFeatureSelector(
    base_model,
    n_features_to_select="auto",
    direction="backward",  # change direction here
).set_output(transform="pandas")
sel.fit(xtrain_pre, ytrain)
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
sel_cols = sel.get_feature_names_out()
print(sel_cols)
# Out:
# ['num__Min.Price' 'num__Price' 'num__MPG.highway' 'num__EngineSize'
#  'num__Horsepower' 'num__RPM' 'num__Rev.per.mile'
#  'num__Fuel.tank.capacity' 'num__Length' 'num__Wheelbase' 'cat__Type'
#  'cat__Origin']

# %%
len(sel_cols)
# Out:
# 12

# %%
xtrain_pre_sel = sel.transform(xtrain_pre)
xtrain_pre_sel.head()
# Out:
#     num__Min.Price  num__Price  num__MPG.highway  num__EngineSize  \
# 42       -0.373824   -0.208643          0.363084        -0.499737
# 53       -0.699007   -0.802086          1.322665        -0.871400
# 21        1.386650    0.998360         -0.596496         0.522338
# 6         0.310182    0.123283         -0.212664         0.986917
# 26       -0.261692   -0.399752         -0.404580        -0.220989
#
#     num__Horsepower  num__RPM  num__Rev.per.mile  num__Fuel.tank.capacity  \
# 42        -0.070927  0.583333           0.553885                 0.094849
# 53        -0.759572  0.416667          -0.190474                -0.664766
# 21         0.059357 -0.750000          -1.020721                -0.208997
# 6          0.487434 -0.750000          -1.431073                 0.398695
# 26        -0.815408 -0.750000           0.277136                -0.208997
#
#     num__Length  num__Wheelbase  cat__Type  cat__Origin
# 42     0.075537        0.450415  -1.373237     1.114641
# 53    -0.832796       -0.913114   0.474391     1.114641
# 21     1.333229        0.904925  -0.757361    -0.897150
# 6      1.123614        1.056428  -0.757361    -0.897150
# 26     0.564640        0.147409  -0.141485    -0.897150

# %%
xtest_pre_sel = sel.transform(xtest_pre)
xtest_pre_sel.head()
# Out:
#     num__Min.Price  num__Price  num__MPG.highway  num__EngineSize  \
# 34       -0.485956   -0.560685          0.171168        -0.685568
# 90        0.646578    0.374742         -0.788412         0.057759
# 3         1.532421    1.823145         -0.596496         0.057759
# 35       -0.295332    0.032758         -1.747992         0.243590
# 19        0.141983   -0.118118         -0.212664         0.522338
#
#     num__Horsepower  num__RPM  num__Rev.per.mile  num__Fuel.tank.capacity  \
# 34        -0.536227  0.416667           0.038559                -0.360920
# 90         0.636330  0.916667           0.124447                 0.550618
# 3          0.524658  0.416667           0.410739                 1.340618
# 35         0.022133 -0.750000          -0.457680                 1.310233
# 19         0.171029  0.083333          -0.629455                 0.398695
#
#     num__Length  num__Wheelbase  cat__Type  cat__Origin
# 34    -0.343694       -0.155598   1.090267    -0.897150
# 90    -1.741130       -1.064618   1.090267     1.114641
# 3      0.634511        0.298912  -0.141485     1.114641
# 35    -0.553309        2.268454   1.706143    -0.897150
# 19     1.333229        1.359435  -0.757361    -0.897150

# %% [markdown]
# # Step 8 - Fit and Evalute the feature selected model

# %%
model_sel = LinearRegression()
model_sel.fit(xtrain_pre_sel, ytrain)
# Out:
# LinearRegression()

# %%
r2_train_sel = model_sel.score(xtrain_pre_sel, ytrain)
print(f"R2 train on selected features : {r2_train_sel:.4f}")
# Out:
# R2 train on selected features : 0.9692

# %%
r2_test_sel = model_sel.score(xtest_pre_sel, ytest)
print(f"R2 test on selected features : {r2_test_sel:.4f}")
# Out:
# R2 test on selected features : 0.8406

# %%
gen_err_sel = abs(r2_train_sel - r2_test_sel)
print(f"Generalization Error on Selected features : {gen_err_sel:.4f}")
# Out:
# Generalization Error on Selected features : 0.1286

# %% [markdown]
# # Step 9 - Evalute model in detail

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score,
)


def evaluate_model(model, x, y):
    ypred = model.predict(x)
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2%}")
    print(f"R2 : {r2:.2%}")

# %%
print("Training Results : ")
evaluate_model(model_sel, xtrain_pre_sel, ytrain)
# Out:
# Training Results :
# RMSE : 107.04
# MAE : 88.49
# MAPE : 2.98%
# R2 : 96.92%

# %%
print("Testing Results : ")
evaluate_model(model_sel, xtest_pre_sel, ytest)
# Out:
# Testing Results :
# RMSE : 192.42
# MAE : 144.06
# MAPE : 4.86%
# R2 : 84.06%

# %% [markdown]
# # Step 10 - Perform out of sample prediction

# %%
xnew = pd.read_csv("sample.csv")
xnew
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Audi      100  Midsize       30.8   37.7       44.6        19
# 1      Pontiac  Sunbird  Compact        9.4   11.1       12.8        23
# 2    Chevrolet   Lumina  Midsize       13.4   15.9       18.4        21
# 3        Mazda     RX-7   Sporty       32.5   32.5       32.5        17
# 4   Volkswagen      Fox    Small        8.7    9.1        9.5        25
#
#    MPG.highway      AirBags DriveTrain  ... Fuel.tank.capacity  Passengers  \
# 0           26          NaN      Front  ...               15.0           6
# 1           31          NaN      Front  ...               15.2           5
# 2           29          NaN      Front  ...               16.5           6
# 3           25  Driver only       Rear  ...               20.0           2
# 4           33          NaN      Front  ...               12.4           4
#
#    Length  Wheelbase  Width Turn.circle  Rear.seat.room  Luggage.room  \
# 0     190        106     65          37            31.0          17.0
# 1     181        101     66          39            25.0          13.0
# 2     198        108     71          40            28.5          16.0
# 3     169         96     69          37             NaN           NaN
# 4     163         93     63          34            26.0          10.0
#
#     Origin              Make
# 0  non-USA          Audi 100
# 1      USA   Pontiac Sunbird
# 2      USA  Chevrolet Lumina
# 3  non-USA        Mazda RX-7
# 4  non-USA    Volkswagen Fox
#
# [5 rows x 26 columns]

# %%
xnew_pre = pre.transform(xnew)
xnew_pre
# Out:
#    num__Min.Price  num__Price  num__Max.Price  num__MPG.city  \
# 0        1.532421    1.823145        1.976445      -0.616405
# 1       -0.867205   -0.852378       -0.807234       0.131365
# 2       -0.418677   -0.369577       -0.317026      -0.242520
# 3        1.723046    1.300111        0.917246      -0.990291
# 4       -0.945698   -1.053545       -1.096106       0.505250
#
#    num__MPG.highway  num__EngineSize  num__Horsepower  num__RPM  \
# 0         -0.596496         0.057759         0.524658  0.416667
# 1          0.363084        -0.685568        -0.629288 -0.083333
# 2         -0.020748        -0.499737        -0.629288 -0.083333
# 3         -0.788412        -1.335979         2.069456  2.083333
# 4          0.746917        -0.871400        -1.169036  0.416667
#
#    num__Rev.per.mile  num__Fuel.tank.capacity  ...  num__Turn.circle  \
# 0           0.410739                -0.512843  ...         -0.679350
# 1           0.658858                -0.452074  ...         -0.062517
# 2           0.525255                -0.057074  ...          0.245900
# 3           0.009930                 1.006387  ...         -0.679350
# 4           0.439368                -1.302842  ...         -1.604599
#
#    num__Rear.seat.room  num__Luggage.room  cat__Manufacturer  cat__Type  \
# 0             1.005208           1.066586          -1.525589  -0.141485
# 1            -0.943754          -0.318105           0.983157  -1.373237
# 2             0.193140           0.720413          -1.047733  -0.141485
# 3            -0.131687           0.028068           0.266373   1.090267
# 4            -0.618927          -1.356622           1.699942   0.474391
#
#    cat__AirBags  cat__DriveTrain  cat__Cylinders  cat__Man.trans.avail  \
# 0     -0.273722        -0.180439        0.975122              0.780189
# 1     -0.273722        -0.180439       -0.763650              0.780189
# 2     -0.273722        -0.180439       -0.763650             -1.281740
# 3     -0.273722         1.727057       -2.502421              0.780189
# 4     -0.273722        -0.180439       -0.763650              0.780189
#
#    cat__Origin
# 0     1.114641
# 1    -0.897150
# 2    -0.897150
# 3     1.114641
# 4     1.114641
#
# [5 rows x 24 columns]

# %%
xnew_pre_sel = sel.transform(xnew_pre)
xnew_pre_sel
# Out:
#    num__Min.Price  num__Price  num__MPG.highway  num__EngineSize  \
# 0        1.532421    1.823145         -0.596496         0.057759
# 1       -0.867205   -0.852378          0.363084        -0.685568
# 2       -0.418677   -0.369577         -0.020748        -0.499737
# 3        1.723046    1.300111         -0.788412        -1.335979
# 4       -0.945698   -1.053545          0.746917        -0.871400
#
#    num__Horsepower  num__RPM  num__Rev.per.mile  num__Fuel.tank.capacity  \
# 0         0.524658  0.416667           0.410739                -0.512843
# 1        -0.629288 -0.083333           0.658858                -0.452074
# 2        -0.629288 -0.083333           0.525255                -0.057074
# 3         2.069456  2.083333           0.009930                 1.006387
# 4        -1.169036  0.416667           0.439368                -1.302842
#
#    num__Length  num__Wheelbase  cat__Type  cat__Origin
# 0     0.424896        0.298912  -0.141485     1.114641
# 1    -0.203950       -0.458604  -1.373237    -0.897150
# 2     0.983870        0.601918  -0.141485    -0.897150
# 3    -1.042412       -1.216121   1.090267     1.114641
# 4    -1.461642       -1.670631   0.474391     1.114641

# %%
preds = model_sel.predict(xnew_pre_sel)
preds
# Out:
# array([3255.60214796, 2700.74236997, 3132.76680149, 3469.66709788,
#        2222.19057096])

# %%
xnew["Weight"] = preds.round(2)
xnew
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Audi      100  Midsize       30.8   37.7       44.6        19
# 1      Pontiac  Sunbird  Compact        9.4   11.1       12.8        23
# 2    Chevrolet   Lumina  Midsize       13.4   15.9       18.4        21
# 3        Mazda     RX-7   Sporty       32.5   32.5       32.5        17
# 4   Volkswagen      Fox    Small        8.7    9.1        9.5        25
#
#    MPG.highway      AirBags DriveTrain  ... Passengers  Length  Wheelbase  \
# 0           26          NaN      Front  ...          6     190        106
# 1           31          NaN      Front  ...          5     181        101
# 2           29          NaN      Front  ...          6     198        108
# 3           25  Driver only       Rear  ...          2     169         96
# 4           33          NaN      Front  ...          4     163         93
#
#    Width  Turn.circle Rear.seat.room  Luggage.room   Origin              Make  \
# 0     65           37           31.0          17.0  non-USA          Audi 100
# 1     66           39           25.0          13.0      USA   Pontiac Sunbird
# 2     71           40           28.5          16.0      USA  Chevrolet Lumina
# 3     69           37            NaN           NaN  non-USA        Mazda RX-7
# 4     63           34           26.0          10.0  non-USA    Volkswagen Fox
#
#     Weight
# 0  3255.60
# 1  2700.74
# 2  3132.77
# 3  3469.67
# 4  2222.19
#
# [5 rows x 27 columns]

# %%
xnew.to_csv("backward_results.csv", index=False)

# %% [markdown]
# # Save the model object and sel and pre

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Min.Price', 'Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Manufacturer', 'Type', 'AirBags',
#                                   'DriveTrain', 'Cylinders', 'Man.trans.avail',
#                                   'Origin'])])

# %%
sel
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
model_sel
# Out:
# LinearRegression()

# %%
import joblib

joblib.dump(pre, "backward_pre.joblib")
# Out:
# ['backward_pre.joblib']

# %%
joblib.dump(sel, "backward_sel.joblib")
# Out:
# ['backward_sel.joblib']

# %%
joblib.dump(model_sel, "backward_model.joblib")
# Out:
# ['backward_model.joblib']

# %%
p = joblib.load("backward_pre.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Min.Price', 'Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Manufacturer', 'Type', 'AirBags',
#                                   'DriveTrain', 'Cylinders', 'Man.trans.avail',
#                                   'Origin'])])

# %%
s = joblib.load("backward_sel.joblib")
s
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
m = joblib.load("backward_model.joblib")
m
# Out:
# LinearRegression()

# %%
m.score(xtrain_pre_sel, ytrain)
# Out:
# 0.9691945897890565

# %%
m.score(xtest_pre_sel, ytest)
# Out:
# 0.8406387686384698
